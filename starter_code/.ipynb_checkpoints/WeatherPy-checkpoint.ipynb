# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
# print(weather_api_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Example of data frame is expecting

#columns for lat, lon, temp_max, humidity, clouds, wind speed, country, date


# use list of units
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
#units = ["imperial"]

# set up list to hold two different temperatures
lat = []
lon = []
temperatures = []
temp_max = []
humidity = []
country = []
clouds = []
date = []
wind_spead = []

cities_found = []

# loop throught the list of units and append them to temperatures list
for city in cities:
    
    # Build query URL based on current element in units
    query_url = url + "q=" + city + "&appid=" + weather_api_key + "&units=imperial"

    # Get weather data
    try:
        print("Found city:"+ city)
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()

        # Get temperature from JSON response
        lat.append(weather_json["coord"]["lat"])
        lon.append(weather_json["coord"]["lon"])
        temperatures.append(weather_json["main"]["temp"])
        temp_max.append(weather_json["main"]["temp_max"])
        humidity.append(weather_json["main"]["humidity"])
        country.append(weather_json["sys"]["country"])
        clouds.append(weather_json["clouds"]["all"])
        date.append(weather_json["dt"])
        wind_speed.append(weather_json["wind"]["speed"])
        
        #Do this last
        cities_found.append(city)
    
    except:
        print("Count not find:"+ city)
        


# Report temperatures by accessing each element in the list
# print(
#     f"The temperature in Bujumbura is {temperatures[0]}C or {temperatures[1]}F.")
# Out:
# Found city:atuona
# Count not find:atuona
# Found city:upernavik
# Count not find:upernavik
# Found city:hobart
# Count not find:hobart
# Found city:ushuaia
# Count not find:ushuaia
# Found city:pevek
# Count not find:pevek
# Found city:shelabolikha
# Count not find:shelabolikha
# Found city:port alfred
# Count not find:port alfred
# Found city:albany
# Count not find:albany
# Found city:vaini
# Count not find:vaini
# Found city:nikolskoye
# Count not find:nikolskoye
# Found city:mataura
# Count not find:mataura
# Found city:sitka
# Count not find:sitka
# Found city:jamestown
# Count not find:jamestown
# Found city:djambala
# Count not find:djambala
# Found city:cape town
# Count not find:cape town
# Found city:luganville
# Count not find:luganville
# Found city:tasiilaq
# Count not find:tasiilaq
# Found city:rikitea
# Count not find:rikitea
# Found city:nizhneyansk
# Count not find:nizhneyansk
# Found city:labuan
# Count not find:labuan
# Found city:butaritari
# Count not find:butaritari
# Found city:illoqqortoormiut
# Count not find:illoqqortoormiut
# Found city:lolua
# Count not find:lolua
# Found city:georgetown
# Count not find:georgetown
# Found city:tezu
# Count not find:tezu
# Found city:lavrentiya
# Count not find:lavrentiya
# Found city:saint george
# Count not find:saint george
# Found city:port elizabeth
# Count not find:port elizabeth
# Found city:belmonte
# Count not find:belmonte
# Found city:matata
# Count not find:matata
# Found city:norman wells
# Count not find:norman wells
# Found city:bilibino
# Count not find:bilibino
# Found city:chokurdakh
# Count not find:chokurdakh
# Found city:kincardine
# Count not find:kincardine
# Found city:hithadhoo
# Count not find:hithadhoo
# Found city:fevralsk
# Count not find:fevralsk
# Found city:hasaki
# Count not find:hasaki
# Found city:yerbogachen
# Count not find:yerbogachen
# Found city:duartina
# Count not find:duartina
# Found city:beihai
# Count not find:beihai
# Found city:terrace bay
# Count not find:terrace bay
# Found city:olafsvik
# Count not find:olafsvik
# Found city:yellowknife
# Count not find:yellowknife
# Found city:bredasdorp
# Count not find:bredasdorp
# Found city:gravdal
# Count not find:gravdal
# Found city:castro
# Count not find:castro
# Found city:kaitangata
# Count not find:kaitangata
# Found city:torbay
# Count not find:torbay
# Found city:fairbanks
# Count not find:fairbanks
# Found city:gondar
# Count not find:gondar
# Found city:punta arenas
# Count not find:punta arenas
# Found city:romanovo
# Count not find:romanovo
# Found city:senador guiomard
# Count not find:senador guiomard
# Found city:virginia beach
# Count not find:virginia beach
# Found city:kostomuksha
# Count not find:kostomuksha
# Found city:kodiak
# Count not find:kodiak
# Found city:carnarvon
# Count not find:carnarvon
# Found city:qaanaaq
# Count not find:qaanaaq
# Found city:bluff
# Count not find:bluff
# Found city:ponta do sol
# Count not find:ponta do sol
# Found city:cabinda
# Count not find:cabinda
# Found city:dikson
# Count not find:dikson
# Found city:vila velha
# Count not find:vila velha
# Found city:bethel
# Count not find:bethel
# Found city:touros
# Count not find:touros
# Found city:tsihombe
# Count not find:tsihombe
# Found city:lompoc
# Count not find:lompoc
# Found city:plettenberg bay
# Count not find:plettenberg bay
# Found city:barentsburg
# Count not find:barentsburg
# Found city:richards bay
# Count not find:richards bay
# Found city:labuhan
# Count not find:labuhan
# Found city:busselton
# Count not find:busselton
# Found city:mys shmidta
# Count not find:mys shmidta
# Found city:hami
# Count not find:hami
# Found city:dingle
# Count not find:dingle
# Found city:bayeux
# Count not find:bayeux
# Found city:souillac
# Count not find:souillac
# Found city:visby
# Count not find:visby
# Found city:kalevala
# Count not find:kalevala
# Found city:fortuna
# Count not find:fortuna
# Found city:coihaique
# Count not find:coihaique
# Found city:tari
# Count not find:tari
# Found city:taolanaro
# Count not find:taolanaro
# Found city:iqaluit
# Count not find:iqaluit
# Found city:paradwip
# Count not find:paradwip
# Found city:portland
# Count not find:portland
# Found city:kapaa
# Count not find:kapaa
# Found city:mentok
# Count not find:mentok
# Found city:skibotn
# Count not find:skibotn
# Found city:winneba
# Count not find:winneba
# Found city:tuatapere
# Count not find:tuatapere
# Found city:warmbad
# Count not find:warmbad
# Found city:bolungarvik
# Count not find:bolungarvik
# Found city:tessalit
# Count not find:tessalit
# Found city:savannakhet
# Count not find:savannakhet
# Found city:carbonear
# Count not find:carbonear
# Found city:waunakee
# Count not find:waunakee
# Found city:rawah
# Count not find:rawah
# Found city:grafton
# Count not find:grafton
# Found city:isangel
# Count not find:isangel
# Found city:himora
# Count not find:himora
# Found city:sentyabrskiy
# Count not find:sentyabrskiy
# Found city:waingapu
# Count not find:waingapu
# Found city:lebu
# Count not find:lebu
# Found city:dalinghe
# Count not find:dalinghe
# Found city:whyalla
# Count not find:whyalla
# Found city:hermanus
# Count not find:hermanus
# Found city:pisco
# Count not find:pisco
# Found city:chuy
# Count not find:chuy
# Found city:rochester
# Count not find:rochester
# Found city:geraldton
# Count not find:geraldton
# Found city:port shepstone
# Count not find:port shepstone
# Found city:semey
# Count not find:semey
# Found city:victoria
# Count not find:victoria
# Found city:springbok
# Count not find:springbok
# Found city:kavieng
# Count not find:kavieng
# Found city:mar del plata
# Count not find:mar del plata
# Found city:albury
# Count not find:albury
# Found city:khatanga
# Count not find:khatanga
# Found city:rungata
# Count not find:rungata
# Found city:berdigestyakh
# Count not find:berdigestyakh
# Found city:hilo
# Count not find:hilo
# Found city:havelock
# Count not find:havelock
# Found city:vylgort
# Count not find:vylgort
# Found city:bargal
# Count not find:bargal
# Found city:melenki
# Count not find:melenki
# Found city:puerto ayora
# Count not find:puerto ayora
# Found city:marawi
# Count not find:marawi
# Found city:perpignan
# Count not find:perpignan
# Found city:buariki
# Count not find:buariki
# Found city:leningradskiy
# Count not find:leningradskiy
# Found city:codrington
# Count not find:codrington
# Found city:severo-kurilsk
# Count not find:severo-kurilsk
# Found city:henties bay
# Count not find:henties bay
# Found city:elko
# Count not find:elko
# Found city:marsh harbour
# Count not find:marsh harbour
# Found city:belushya guba
# Count not find:belushya guba
# Found city:saint-georges
# Count not find:saint-georges
# Found city:doha
# Count not find:doha
# Found city:kabalo
# Count not find:kabalo
# Found city:wajima
# Count not find:wajima
# Found city:guerrero negro
# Count not find:guerrero negro
# Found city:vinh
# Count not find:vinh
# Found city:ouegoa
# Count not find:ouegoa
# Found city:gondanglegi
# Count not find:gondanglegi
# Found city:dunda
# Count not find:dunda
# Found city:srednekolymsk
# Count not find:srednekolymsk
# Found city:angoche
# Count not find:angoche
# Found city:antofagasta
# Count not find:antofagasta
# Found city:belaya gora
# Count not find:belaya gora
# Found city:galgani
# Count not find:galgani
# Found city:saint-francois
# Count not find:saint-francois
# Found city:mortka
# Count not find:mortka
# Found city:sabang
# Count not find:sabang
# Found city:saskylakh
# Count not find:saskylakh
# Found city:corrente
# Count not find:corrente
# Found city:port-gentil
# Count not find:port-gentil
# Found city:honningsvag
# Count not find:honningsvag
# Found city:skibbereen
# Count not find:skibbereen
# Found city:tyrma
# Count not find:tyrma
# Found city:leogane
# Count not find:leogane
# Found city:saint-philippe
# Count not find:saint-philippe
# Found city:maumere
# Count not find:maumere
# Found city:bambous virieux
# Count not find:bambous virieux
# Found city:acapulco
# Count not find:acapulco
# Found city:college
# Count not find:college
# Found city:aklavik
# Count not find:aklavik
# Found city:cabo san lucas
# Count not find:cabo san lucas
# Found city:arraial do cabo
# Count not find:arraial do cabo
# Found city:avarua
# Count not find:avarua
# Found city:kruisfontein
# Count not find:kruisfontein
# Found city:ancud
# Count not find:ancud
# Found city:chapais
# Count not find:chapais
# Found city:faanui
# Count not find:faanui
# Found city:satitoa
# Count not find:satitoa
# Found city:pala
# Count not find:pala
# Found city:ilulissat
# Count not find:ilulissat
# Found city:provideniya
# Count not find:provideniya
# Found city:utiroa
# Count not find:utiroa
# Found city:haukipudas
# Count not find:haukipudas
# Found city:tuktoyaktuk
# Count not find:tuktoyaktuk
# Found city:dubai
# Count not find:dubai
# Found city:cristalina
# Count not find:cristalina
# Found city:samusu
# Count not find:samusu
# Found city:mahebourg
# Count not find:mahebourg
# Found city:hofn
# Count not find:hofn
# Found city:araouane
# Count not find:araouane
# Found city:chushan
# Count not find:chushan
# Found city:makaha
# Count not find:makaha
# Found city:namatanai
# Count not find:namatanai
# Found city:kon tum
# Count not find:kon tum
# Found city:north bend
# Count not find:north bend
# Found city:airai
# Count not find:airai
# Found city:mangaratiba
# Count not find:mangaratiba
# Found city:te anau
# Count not find:te anau
# Found city:alberton
# Count not find:alberton
# Found city:tigzirt
# Count not find:tigzirt
# Found city:brownfield
# Count not find:brownfield
# Found city:new norfolk
# Count not find:new norfolk
# Found city:inta
# Count not find:inta
# Found city:lodja
# Count not find:lodja
# Found city:assare
# Count not find:assare
# Found city:mount gambier
# Count not find:mount gambier
# Found city:marcona
# Count not find:marcona
# Found city:ridgecrest
# Count not find:ridgecrest
# Found city:cliza
# Count not find:cliza
# Found city:trelew
# Count not find:trelew
# Found city:ouagadougou
# Count not find:ouagadougou
# Found city:santa rosalia
# Count not find:santa rosalia
# Found city:sidi bu zayd
# Count not find:sidi bu zayd
# Found city:luena
# Count not find:luena
# Found city:mitsamiouli
# Count not find:mitsamiouli
# Found city:mountain home
# Count not find:mountain home
# Found city:alofi
# Count not find:alofi
# Found city:ballina
# Count not find:ballina
# Found city:san quintin
# Count not find:san quintin
# Found city:takoradi
# Count not find:takoradi
# Found city:tahta
# Count not find:tahta
# Found city:roura
# Count not find:roura
# Found city:lincolnton
# Count not find:lincolnton
# Found city:maceio
# Count not find:maceio
# Found city:klaksvik
# Count not find:klaksvik
# Found city:gigmoto
# Count not find:gigmoto
# Found city:port antonio
# Count not find:port antonio
# Found city:kollam
# Count not find:kollam
# Found city:longyearbyen
# Count not find:longyearbyen
# Found city:barrow
# Count not find:barrow
# Found city:moen
# Count not find:moen
# Found city:carauari
# Count not find:carauari
# Found city:tongren
# Count not find:tongren
# Found city:minab
# Count not find:minab
# Found city:dunedin
# Count not find:dunedin
# Found city:changde
# Count not find:changde
# Found city:puerto colombia
# Count not find:puerto colombia
# Found city:hualmay
# Count not find:hualmay
# Found city:east london
# Count not find:east london
# Found city:karatau
# Count not find:karatau
# Found city:conakry
# Count not find:conakry
# Found city:kirakira
# Count not find:kirakira
# Found city:moron
# Count not find:moron
# Found city:jeremie
# Count not find:jeremie
# Found city:coquimbo
# Count not find:coquimbo
# Found city:burgeo
# Count not find:burgeo
# Found city:baruun-urt
# Count not find:baruun-urt
# Found city:attawapiskat
# Count not find:attawapiskat
# Found city:komsomolskiy
# Count not find:komsomolskiy
# Found city:svetlyy
# Count not find:svetlyy
# Found city:gat
# Count not find:gat
# Found city:margate
# Count not find:margate
# Found city:truth or consequences
# Count not find:truth or consequences
# Found city:bengkulu
# Count not find:bengkulu
# Found city:narsaq
# Count not find:narsaq
# Found city:emerald
# Count not find:emerald
# Found city:faya
# Count not find:faya
# Found city:half moon bay
# Count not find:half moon bay
# Found city:lerwick
# Count not find:lerwick
# Found city:alice springs
# Count not find:alice springs
# Found city:harbour breton
# Count not find:harbour breton
# Found city:ayagoz
# Count not find:ayagoz
# Found city:vestmanna
# Count not find:vestmanna
# Found city:siguiri
# Count not find:siguiri
# Found city:port hardy
# Count not find:port hardy
# Found city:nazareno
# Count not find:nazareno
# Found city:atlantic city
# Count not find:atlantic city
# Found city:flinders
# Count not find:flinders
# Found city:gidole
# Count not find:gidole
# Found city:salinas
# Count not find:salinas
# Found city:tiksi
# Count not find:tiksi
# Found city:micheweni
# Count not find:micheweni
# Found city:valenca
# Count not find:valenca
# Found city:kondinskoye
# Count not find:kondinskoye
# Found city:lakes entrance
# Count not find:lakes entrance
# Found city:mogadishu
# Count not find:mogadishu
# Found city:thompson
# Count not find:thompson
# Found city:mandalgovi
# Count not find:mandalgovi
# Found city:verkhnetulomskiy
# Count not find:verkhnetulomskiy
# Found city:morgan city
# Count not find:morgan city
# Found city:siyabuswa
# Count not find:siyabuswa
# Found city:lagoa
# Count not find:lagoa
# Found city:ambulu
# Count not find:ambulu
# Found city:nioro
# Count not find:nioro
# Found city:luwuk
# Count not find:luwuk
# Found city:praia da vitoria
# Count not find:praia da vitoria
# Found city:milingimbi
# Count not find:milingimbi
# Found city:georgiyevka
# Count not find:georgiyevka
# Found city:nicoya
# Count not find:nicoya
# Found city:port macquarie
# Count not find:port macquarie
# Found city:kloulklubed
# Count not find:kloulklubed
# Found city:los llanos de aridane
# Count not find:los llanos de aridane
# Found city:kidal
# Count not find:kidal
# Found city:tutoia
# Count not find:tutoia
# Found city:gornopravdinsk
# Count not find:gornopravdinsk
# Found city:metro
# Count not find:metro
# Found city:luderitz
# Count not find:luderitz
# Found city:kahului
# Count not find:kahului
# Found city:saldanha
# Count not find:saldanha
# Found city:rio gallegos
# Count not find:rio gallegos
# Found city:banda aceh
# Count not find:banda aceh
# Found city:caucaia
# Count not find:caucaia
# Found city:ribeira grande
# Count not find:ribeira grande
# Found city:katsuura
# Count not find:katsuura
# Found city:beringovskiy
# Count not find:beringovskiy
# Found city:ust-kulom
# Count not find:ust-kulom
# Found city:jasper
# Count not find:jasper
# Found city:hobyo
# Count not find:hobyo
# Found city:kaeo
# Count not find:kaeo
# Found city:saleaula
# Count not find:saleaula
# Found city:ulety
# Count not find:ulety
# Found city:cherskiy
# Count not find:cherskiy
# Found city:lakatoro
# Count not find:lakatoro
# Found city:bilma
# Count not find:bilma
# Found city:bonnyville
# Count not find:bonnyville
# Found city:dolbeau
# Count not find:dolbeau
# Found city:hay river
# Count not find:hay river
# Found city:padang
# Count not find:padang
# Found city:sika
# Count not find:sika
# Found city:nsanje
# Count not find:nsanje
# Found city:placido de castro
# Count not find:placido de castro
# Found city:boralday
# Count not find:boralday
# Found city:belyy yar
# Count not find:belyy yar
# Found city:mount isa
# Count not find:mount isa
# Found city:merauke
# Count not find:merauke
# Found city:paamiut
# Count not find:paamiut
# Found city:tsienyane
# Count not find:tsienyane
# Found city:kununurra
# Count not find:kununurra
# Found city:north platte
# Count not find:north platte
# Found city:pedernales
# Count not find:pedernales
# Found city:umea
# Count not find:umea
# Found city:nanga eboko
# Count not find:nanga eboko
# Found city:singaraja
# Count not find:singaraja
# Found city:saint-gaudens
# Count not find:saint-gaudens
# Found city:puerto escondido
# Count not find:puerto escondido
# Found city:manono
# Count not find:manono
# Found city:neryungri
# Count not find:neryungri
# Found city:adeje
# Count not find:adeje
# Found city:cheuskiny
# Count not find:cheuskiny
# Found city:totana
# Count not find:totana
# Found city:amahai
# Count not find:amahai
# Found city:pascagoula
# Count not find:pascagoula
# Found city:bireun
# Count not find:bireun
# Found city:shemgang
# Count not find:shemgang
# Found city:jiwani
# Count not find:jiwani
# Found city:itaituba
# Count not find:itaituba
# Found city:cognac
# Count not find:cognac
# Found city:ugoofaaru
# Count not find:ugoofaaru
# Found city:sao joao da barra
# Count not find:sao joao da barra
# Found city:baberu
# Count not find:baberu
# Found city:tura
# Count not find:tura
# Found city:tiznit
# Count not find:tiznit
# Found city:maniitsoq
# Count not find:maniitsoq
# Found city:batemans bay
# Count not find:batemans bay
# Found city:saveh
# Count not find:saveh
# Found city:nishihara
# Count not find:nishihara
# Found city:barda
# Count not find:barda
# Found city:peterhead
# Count not find:peterhead
# Found city:san policarpo
# Count not find:san policarpo
# Found city:ilinskiy
# Count not find:ilinskiy
# Found city:les cayes
# Count not find:les cayes
# Found city:pochutla
# Count not find:pochutla
# Found city:meyungs
# Count not find:meyungs
# Found city:bonavista
# Count not find:bonavista
# Found city:kizilskoye
# Count not find:kizilskoye
# Found city:tigil
# Count not find:tigil
# Found city:nyrob
# Count not find:nyrob
# Found city:shagonar
# Count not find:shagonar
# Found city:aflu
# Count not find:aflu
# Found city:dehloran
# Count not find:dehloran
# Found city:constitucion
# Count not find:constitucion
# Found city:sohag
# Count not find:sohag
# Found city:gawler
# Count not find:gawler
# Found city:vysokogornyy
# Count not find:vysokogornyy
# Found city:halalo
# Count not find:halalo
# Found city:sao filipe
# Count not find:sao filipe
# Found city:krasnoselkup
# Count not find:krasnoselkup
# Found city:crotone
# Count not find:crotone
# Found city:masjed-e soleyman
# Count not find:masjed-e soleyman
# Found city:esperance
# Count not find:esperance
# Found city:noumea
# Count not find:noumea
# Found city:yenagoa
# Count not find:yenagoa
# Found city:egvekinot
# Count not find:egvekinot
# Found city:kodinsk
# Count not find:kodinsk
# Found city:general pico
# Count not find:general pico
# Found city:igarka
# Count not find:igarka
# Found city:nanortalik
# Count not find:nanortalik
# Found city:bani
# Count not find:bani
# Found city:healesville
# Count not find:healesville
# Found city:tumannyy
# Count not find:tumannyy
# Found city:haines junction
# Count not find:haines junction
# Found city:buqayq
# Count not find:buqayq
# Found city:ossora
# Count not find:ossora
# Found city:hambantota
# Count not find:hambantota
# Found city:ciudad bolivar
# Count not find:ciudad bolivar
# Found city:hagere hiywet
# Count not find:hagere hiywet
# Found city:buraydah
# Count not find:buraydah
# Found city:magistralnyy
# Count not find:magistralnyy
# Found city:nguiu
# Count not find:nguiu
# Found city:meulaboh
# Count not find:meulaboh
# Found city:rawson
# Count not find:rawson
# Found city:nkhata bay
# Count not find:nkhata bay
# Found city:zhuhai
# Count not find:zhuhai
# Found city:lodwar
# Count not find:lodwar
# Found city:morros
# Count not find:morros
# Found city:flagstaff
# Count not find:flagstaff
# Found city:storforshei
# Count not find:storforshei
# Found city:caravelas
# Count not find:caravelas
# Found city:sinnamary
# Count not find:sinnamary
# Found city:nador
# Count not find:nador
# Found city:male
# Count not find:male
# Found city:camabatela
# Count not find:camabatela
# Found city:pitimbu
# Count not find:pitimbu
# Found city:comodoro rivadavia
# Count not find:comodoro rivadavia
# Found city:trincomalee
# Count not find:trincomalee
# Found city:namibe
# Count not find:namibe
# Found city:broome
# Count not find:broome
# Found city:kristiansund
# Count not find:kristiansund
# Found city:tokur
# Count not find:tokur
# Found city:tanabe
# Count not find:tanabe
# Found city:boo
# Count not find:boo
# Found city:vallenar
# Count not find:vallenar
# Found city:sandovo
# Count not find:sandovo
# Found city:fort wellington
# Count not find:fort wellington
# Found city:necochea
# Count not find:necochea
# Found city:carutapera
# Count not find:carutapera
# Found city:strezhevoy
# Count not find:strezhevoy
# Found city:deputatskiy
# Count not find:deputatskiy
# Found city:ithaca
# Count not find:ithaca
# Found city:grootfontein
# Count not find:grootfontein
# Found city:nyurba
# Count not find:nyurba
# Found city:zhigansk
# Count not find:zhigansk
# Found city:ostrovnoy
# Count not find:ostrovnoy
# Found city:opuwo
# Count not find:opuwo
# Found city:yeroham
# Count not find:yeroham
# Found city:jalu
# Count not find:jalu
# Found city:iralaya
# Count not find:iralaya
# Found city:ojinaga
# Count not find:ojinaga
# Found city:kuroiso
# Count not find:kuroiso
# Found city:iquitos
# Count not find:iquitos
# Found city:bandarbeyla
# Count not find:bandarbeyla
# Found city:along
# Count not find:along
# Found city:waipawa
# Count not find:waipawa
# Found city:sola
# Count not find:sola
# Found city:glina
# Count not find:glina
# Found city:sechura
# Count not find:sechura
# Found city:general roca
# Count not find:general roca
# Found city:mongo
# Count not find:mongo
# Found city:korla
# Count not find:korla
# Found city:moerai
# Count not find:moerai
# Found city:cidreira
# Count not find:cidreira
# Found city:san patricio
# Count not find:san patricio
# Found city:la joya
# Count not find:la joya
# Found city:manggar
# Count not find:manggar
# Found city:skorodnoye
# Count not find:skorodnoye
# Found city:ulladulla
# Count not find:ulladulla
# Found city:la ronge
# Count not find:la ronge
# Found city:boundiali
# Count not find:boundiali
# Found city:coos bay
# Count not find:coos bay
# Found city:at-bashi
# Count not find:at-bashi
# Found city:marsa matruh
# Count not find:marsa matruh
# Found city:la palma
# Count not find:la palma
# Found city:arlit
# Count not find:arlit
# Found city:clyde river
# Count not find:clyde river
# Found city:tosya
# Count not find:tosya
# Found city:sindor
# Count not find:sindor
# Found city:vao
# Count not find:vao
# Found city:raudeberg
# Count not find:raudeberg
# Found city:conde
# Count not find:conde
# Found city:clifton
# Count not find:clifton
# Found city:nome
# Count not find:nome
# Found city:warqla
# Count not find:warqla
# Found city:sisimiut
# Count not find:sisimiut
# Found city:salalah
# Count not find:salalah
# Found city:cayenne
# Count not find:cayenne
# Found city:kashary
# Count not find:kashary
# Found city:tunxi
# Count not find:tunxi
# Found city:beloha
# Count not find:beloha
# Found city:ustrzyki dolne
# Count not find:ustrzyki dolne
# Found city:mwinilunga
# Count not find:mwinilunga
# Found city:khonuu
# Count not find:khonuu
# Found city:vestmannaeyjar
# Count not find:vestmannaeyjar
# Found city:savannah bight
# Count not find:savannah bight
# Found city:qasigiannguit
# Count not find:qasigiannguit
# Found city:two rivers
# Count not find:two rivers
# Found city:ust-tsilma
# Count not find:ust-tsilma
# Found city:imbituba
# Count not find:imbituba
# Found city:sur
# Count not find:sur
# Found city:ferrol
# Count not find:ferrol
# Found city:berbera
# Count not find:berbera
# Found city:chandbali
# Count not find:chandbali
# Found city:lom sak
# Count not find:lom sak
# Found city:amapa
# Count not find:amapa
# Found city:talcahuano
# Count not find:talcahuano
# Found city:sinegorye
# Count not find:sinegorye
# Found city:timmins
# Count not find:timmins
# Found city:venado tuerto
# Count not find:venado tuerto
# Found city:leh
# Count not find:leh
# Found city:haibowan
# Count not find:haibowan
# Found city:port augusta
# Count not find:port augusta
# Found city:tomatlan
# Count not find:tomatlan
# Found city:port hedland
# Count not find:port hedland
# Found city:spearfish
# Count not find:spearfish
# Found city:sept-iles
# Count not find:sept-iles
# Found city:okhotsk
# Count not find:okhotsk
# Found city:sioux lookout
# Count not find:sioux lookout
# Found city:suileng
# Count not find:suileng
# Found city:amderma
# Count not find:amderma
# Found city:mamakan
# Count not find:mamakan
# Found city:durban
# Count not find:durban
# Found city:gora kalwaria
# Count not find:gora kalwaria
# Found city:ortakoy
# Count not find:ortakoy
# Found city:verkhnedneprovskiy
# Count not find:verkhnedneprovskiy
# Found city:tubruq
# Count not find:tubruq
# Found city:qaqortoq
# Count not find:qaqortoq
# Found city:molteno
# Count not find:molteno
# Found city:louisbourg
# Count not find:louisbourg
# Found city:palabuhanratu
# Count not find:palabuhanratu
# Found city:rorvik
# Count not find:rorvik
# Found city:port lincoln
# Count not find:port lincoln
# Found city:makakilo city
# Count not find:makakilo city
# Found city:vytegra
# Count not find:vytegra
# Found city:iguape
# Count not find:iguape
# Found city:caconda
# Count not find:caconda
# Found city:conceicao do araguaia
# Count not find:conceicao do araguaia
# Found city:kamaishi
# Count not find:kamaishi
# Found city:san cristobal
# Count not find:san cristobal
# Found city:puerto rondon
# Count not find:puerto rondon
# Found city:ponta delgada
# Count not find:ponta delgada
# Found city:pangoa
# Count not find:pangoa
# Found city:sao felix do xingu
# Count not find:sao felix do xingu
# Found city:inhambane
# Count not find:inhambane
# Found city:shchigry
# Count not find:shchigry
# Found city:ucluelet
# Count not find:ucluelet
# Found city:yulara
# Count not find:yulara
# Found city:ornskoldsvik
# Count not find:ornskoldsvik
# Found city:quatre cocos
# Count not find:quatre cocos
# Found city:hamilton
# Count not find:hamilton
# Found city:la orilla
# Count not find:la orilla
# Found city:oranjemund
# Count not find:oranjemund
# Found city:huarmey
# Count not find:huarmey
# Found city:villazon
# Count not find:villazon
# Found city:kupang
# Count not find:kupang
# Found city:uthal
# Count not find:uthal
# Found city:robertsport
# Count not find:robertsport
# Found city:selcuk
# Count not find:selcuk
# Found city:key west
# Count not find:key west
# Found city:grindavik
# Count not find:grindavik
# Found city:naze
# Count not find:naze
# Found city:verkhnyaya toyma
# Count not find:verkhnyaya toyma
# Found city:khorixas
# Count not find:khorixas
# Found city:wangqing
# Count not find:wangqing
# Found city:ishigaki
# Count not find:ishigaki
# Found city:sofiyivka
# Count not find:sofiyivka
# Found city:maua
# Count not find:maua
# Found city:babanusah
# Count not find:babanusah
# Found city:sakakah
# Count not find:sakakah
# Found city:vostok
# Count not find:vostok
# Found city:navalgund
# Count not find:navalgund
# Found city:stubbekobing
# Count not find:stubbekobing
# Found city:daru
# Count not find:daru
# Found city:tahe
# Count not find:tahe
# Found city:salym
# Count not find:salym
# Found city:san rafael
# Count not find:san rafael
# Found city:toktogul
# Count not find:toktogul
# Found city:havre-saint-pierre
# Count not find:havre-saint-pierre
# Found city:burns lake
# Count not find:burns lake
# Found city:jutai
# Count not find:jutai
# Found city:quelimane
# Count not find:quelimane
# Found city:aberdeen
# Count not find:aberdeen
# Found city:harper
# Count not find:harper
# Found city:cockburn town
# Count not find:cockburn town
# Found city:tamandare
# Count not find:tamandare
# Found city:bloemhof
# Count not find:bloemhof
# Found city:yialos
# Count not find:yialos
# Found city:ust-kamchatsk
# Count not find:ust-kamchatsk
# Found city:muros
# Count not find:muros
# Found city:myingyan
# Count not find:myingyan
# Found city:bestobe
# Count not find:bestobe
# Found city:ust-uda
# Count not find:ust-uda
# Found city:dashitou
# Count not find:dashitou
# Found city:sistranda
# Count not find:sistranda
# Found city:najran
# Count not find:najran
# Found city:beidao
# Count not find:beidao
# Found city:lucea
# Count not find:lucea
# Found city:verkhnyaya inta
# Count not find:verkhnyaya inta
# Found city:grand river south east
# Count not find:grand river south east
# Found city:zyryanovsk
# Count not find:zyryanovsk
# Found city:launceston
# Count not find:launceston
# Found city:peniche
# Count not find:peniche
# Found city:pokrovsk
# Count not find:pokrovsk
# Found city:verkhoyansk
# Count not find:verkhoyansk
# Found city:silivri
# Count not find:silivri
# Found city:tabiauea
# Count not find:tabiauea

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df = pd.DataFrame({
    "City":cities,
    "Latitude": lat,
    "Longitude": lon,
    "Temperatures": temperatures,
    "Temp Max":tem_max,
    "Humidity":humidity,
    "Country": country,
    "Clouds": clouds,
    "Date": date,
    "Wind Speed": wind_speed,
    
})
cities_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-9c1084729b13> in <module>
#       4     "Longitude": lon,
#       5     "Temperatures": temperatures,
# ----> 6     "Temp Max":tem_max,
#       7     "Humidity":humidity,
#       8     "Country": country,
#
# NameError: name 'tem_max' is not defined

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
